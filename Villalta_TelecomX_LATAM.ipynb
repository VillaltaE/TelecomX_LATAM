# %% [markdown]
# <a href="https://colab.research.google.com/github/VillaltaE/TelecomX_LATAM/blob/main/Villalta_TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
#df = pd.read_json('/content/TelecomX_Data.json')
# The original URL points to the GitHub webpage, not the raw file.
# Replace with the raw URL of the JSON file.
df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# #🔧 Transformación

# %%
#Normalizar datos
df_phone = pd.json_normalize(df['phone'])
df_internet = pd.json_normalize(df['internet'])
df_account = pd.json_normalize(df['account'])

# %%
#Normalizar datos
df_customer = pd.json_normalize(df['customer'])
df_customer.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes        Yes       9
# 1    Male              0      No         No       9
# 2    Male              0      No         No       4
# 3    Male              1     Yes         No      13
# 4  Female              1     Yes         No       3

# %%
df_account.head()
# Out:
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0        One year              Yes      Mailed check             65.6
# 1  Month-to-month               No      Mailed check             59.9
# 2  Month-to-month              Yes  Electronic check             73.9
# 3  Month-to-month              Yes  Electronic check             98.0
# 4  Month-to-month              Yes      Mailed check             83.9
#
#   Charges.Total
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df_mod = df.drop(['customer', 'phone', 'internet', 'account'], axis=1)
df_mod.head()
# Out:
#    customerID Churn
# 0  0002-ORFBO    No
# 1  0003-MKNFE    No
# 2  0004-TLHLJ   Yes
# 3  0011-IGKFF   Yes
# 4  0013-EXCHZ   Yes

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
#Se generó un DF uniendo los anteriores
df = pd.concat([df_mod, df_customer, df_phone, df_internet, df_account], axis=1)
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
#Comprbando si hay incoherencia en los datos. Charges.Total aparece com object y debe ser float
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Reemplace el signo de dólar y cualquier espacio en blanco, luego convierta a numérico
# convirtiendo errores a NaN

#Asegúrese de que la columna se trate como una cadena antes de usar str
df['Charges.Total'] = df['Charges.Total'].astype(str)

df['Charges.Total'] = df['Charges.Total'].str.replace('$', '', regex=False).str.strip()
df['Charges.Total'] = pd.to_numeric(df['Charges.Total'], errors='coerce')


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df.sample(n=5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 3225  4503-BDXBD   Yes    Male              0      No         No      11
# 3921  5360-XGYAZ    No    Male              0     Yes        Yes      72
# 5907  8067-NIOYM    No  Female              0     Yes        Yes      24
# 3860  5287-QWLKY   Yes    Male              1     Yes        Yes      71
# 4021  5499-MBERC          Male              0      No         No       3
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# 3225          Yes                No     Fiber optic  ...                  Yes
# 3921           No  No phone service             DSL  ...                  Yes
# 5907          Yes                No              No  ...  No internet service
# 3860          Yes               Yes     Fiber optic  ...                  Yes
# 4021           No  No phone service             DSL  ...                  Yes
#
# ...

# %%
# Revisando los valores nulos del DF
print(df["Charges.Total"].isnull().sum())
# Out:
# 11

# %%
# Asignadole valor 0 a los datos nulos
df["Charges.Total"] = df["Charges.Total"].fillna(0)

# %%
#Comprobacion si hay incoherencia en los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
#Revisar DF con df[df["Charges.Total"] == 0]
df_charges_zero = df[df["Charges.Total"] == 0]
df_charges_zero
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
#Asignandole valor mensual a los valores o porque se asume que son nuevos clientes
df.loc[df["Charges.Total"] == 0, "Charges.Total"] = df["Charges.Monthly"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
#Se iincluye columna cuentas diarias
df['Cuentas.Diarias'] = round(df['Charges.Monthly']/30.4,2)

# %%
#Se revisa como quedó el DF
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0          Yes            No             DSL  ...               No
# 1          Yes           Yes             DSL  ...               No
# 2          Yes            No     Fiber optic  ...              Yes
# 3          Yes            No     Fiber optic  ...              Yes
# 4          Yes            No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
#Cambiar los Yes a 1 y los No a cero en todo el DF
df = df.replace({'Yes': 1, 'No': 0})
# Out:
# <ipython-input-146-e96bd7ea8c33>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({'Yes': 1, 'No': 0})

# %%
#Se revisa como quedó el DF
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO     0  Female              0        1           1       9
# 1  0003-MKNFE     0    Male              0        0           0       9
# 2  0004-TLHLJ     1    Male              0        0           0       4
# 3  0011-IGKFF     1    Male              1        1           0      13
# 4  0013-EXCHZ     1  Female              1        1           0       3
#
#    PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0             1             0             DSL  ...                0
# 1             1             1             DSL  ...                0
# 2             1             0     Fiber optic  ...                1
# 3             1             0     Fiber optic  ...                1
# 4             1             0     Fiber optic  ...                0
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# Analisis de los usuarios que se salieron
df_yes_churn = df[df['Churn'] == 1].copy()

# %%
# Analisis de los usuarios que se salieron
df_yes_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1869 entries, 2 to 7263
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1869 non-null   object
#  1   Churn             1869 non-null   object
#  2   gender            1869 non-null   object
#  3   SeniorCitizen     1869 non-null   int64
#  4   Partner           1869 non-null   int64
#  5   Dependents        1869 non-null   int64
#  6   tenure            1869 non-null   int64
#  7   PhoneService      1869 non-null   int64
#  8   MultipleLines     1869 non-null   object
#  9   InternetService   1869 non-null   object
#  10  OnlineSecurity    1869 non-null   object
#  11  OnlineBackup      1869 non-null   object
#  12  DeviceProtection  1869 non-null   object
#  13  TechSupport       1869 non-null   object
#  14  StreamingTV       1869 non-null   object
#  15  StreamingMovies   1869 non-null   object
# ...

# %%
# Analisis de los usuarios que se salieron
df_yes_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1869 entries, 2 to 7263
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1869 non-null   object
#  1   Churn             1869 non-null   object
#  2   gender            1869 non-null   object
#  3   SeniorCitizen     1869 non-null   int64
#  4   Partner           1869 non-null   int64
#  5   Dependents        1869 non-null   int64
#  6   tenure            1869 non-null   int64
#  7   PhoneService      1869 non-null   int64
#  8   MultipleLines     1869 non-null   object
#  9   InternetService   1869 non-null   object
#  10  OnlineSecurity    1869 non-null   object
#  11  OnlineBackup      1869 non-null   object
#  12  DeviceProtection  1869 non-null   object
#  13  TechSupport       1869 non-null   object
#  14  StreamingTV       1869 non-null   object
#  15  StreamingMovies   1869 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
#Clientes que se salieron
df_yes_churn.describe()
# Out:
#        SeniorCitizen      Partner   Dependents       tenure  PhoneService  \
# count    1869.000000  1869.000000  1869.000000  1869.000000   1869.000000
# mean        0.254682     0.357945     0.174425    17.979133      0.909042
# std         0.435799     0.479524     0.379576    19.531123      0.287626
# min         0.000000     0.000000     0.000000     1.000000      0.000000
# 25%         0.000000     0.000000     0.000000     2.000000      1.000000
# 50%         0.000000     0.000000     0.000000    10.000000      1.000000
# 75%         1.000000     1.000000     0.000000    29.000000      1.000000
# max         1.000000     1.000000     1.000000    72.000000      1.000000
#
#        PaperlessBilling  Charges.Monthly  Charges.Total  Cuentas.Diarias
# count       1869.000000      1869.000000    1869.000000      1869.000000
# mean           0.749064        74.441332    1531.796094         2.448801
# std            0.433668        24.666053    1890.822994         0.811524
# ...

# %%
# Analisis de los usuarios que no se salieron
df_no_churn = df[df['Churn'] == 0].copy()

# %%
# Analisis de los usuarios que no se salieron
df_no_churn.describe()
# Out:
#        SeniorCitizen      Partner   Dependents       tenure  PhoneService  \
# count    5174.000000  5174.000000  5174.000000  5174.000000   5174.000000
# mean        0.128721     0.528218     0.344801    37.569965      0.901044
# std         0.334923     0.499251     0.475349    24.113777      0.298632
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000    15.000000      1.000000
# 50%         0.000000     1.000000     0.000000    38.000000      1.000000
# 75%         0.000000     1.000000     1.000000    61.000000      1.000000
# max         1.000000     1.000000     1.000000    72.000000      1.000000
#
#        PaperlessBilling  Charges.Monthly  Charges.Total  Cuentas.Diarias
# count       5174.000000      5174.000000    5174.000000      5174.000000
# mean           0.535562        61.265124    2549.999497         2.015298
# std            0.498782        31.092648    2329.858843         1.022838
# ...

# %%
#Graficar el estatus de los evasores vs no evasores
no_churn = df[df['Churn'] == 0]
yes_churn = df[df['Churn'] == 1]

# Obtenga el recuento total de los clientes evasores y no evasores
no_churn_count = len(df[df['Churn'] == 0])
yes_churn_count = len(df[df['Churn'] == 1])
fig,ax = plt.subplots(1,1,figsize=(10,4))

#Crea una lista de etiquetas y recuentos correspondientes para las barras.
labels = ['No Evadido', 'Evadido']
counts = [no_churn_count, yes_churn_count]

#Crea el gráfico de barras. El primer argumento es la posición x o las etiquetas,
# y el segundo es la altura de las barras.
bars = ax.bar(labels, counts, label='Churn Status')

# Incluye leyenda
ax.legend()

# agregue títulos y etiquetas para mayor claridad.
ax.set_title('Distribución de estatus de evasión')
ax.set_xlabel('Estatus de evasión')
ax.set_ylabel('Número de clientes')

# Agregar los números de clientes en las barras
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom')

plt.show()

# %%
# Calculate the total number of customers
# Calcula el número total de clientes
total_customers = len(df)

# Calculate the percentages
# Calcula los porcentajes
percentages = [count / total_customers * 100 for count in counts]

fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.pie(percentages, labels=labels, autopct='%1.1f%%', startangle=90)
ax.set_title('Porcentaje de Clientes por Estatus de Evasión (Gráfico de Pastel)')
ax.axis('equal')  # Aspecto igual asegura que el pastel se dibuja como un círculo.
plt.show()

# %%
#Datos de gender de los que se fueron
#no_churn.groupby('InternetService')['InternetService'].count()
yes_churn.groupby('gender')['gender'].count()  # se van mas mujeres respecto a hombres
# Out:
# gender
# Female    939
# Male      930
# Name: gender, dtype: int64

# %%
#Datos de gender de los que se no se fueron

no_churn.groupby('gender')['gender'].count()
# Out:
# gender
# Female    2549
# Male      2625
# Name: gender, dtype: int64

# %%
#Agrupando por tipo de contrato de los que se van
yes_churn.groupby('Contract')['Contract'].count() # Se van mas lo de contrato: 'Month-to-Month'
# Out:
# Contract
# Month-to-month    1655
# One year           166
# Two year            48
# Name: Contract, dtype: int64

# %%
#Agrupando por tipo de contrato de los que se no se  van
no_churn.groupby('Contract')['Contract'].count()
# Out:
# Contract
# Month-to-month    2220
# One year          1307
# Two year          1647
# Name: Contract, dtype: int64

# %%
#Agrupando por método de pago de los que se van
yes_churn.groupby('PaymentMethod')['PaymentMethod'].count()
# Out:
# PaymentMethod
# Bank transfer (automatic)     258
# Credit card (automatic)       232
# Electronic check             1071
# Mailed check                  308
# Name: PaymentMethod, dtype: int64

# %%
#Agrupando por método de pago de los que no se van
no_churn.groupby('PaymentMethod')['PaymentMethod'].count()
# Out:
# PaymentMethod
# Bank transfer (automatic)    1286
# Credit card (automatic)      1290
# Electronic check             1294
# Mailed check                 1304
# Name: PaymentMethod, dtype: int64

# %%
#Agrupando por tiempo de servicio de los que se van
yes_churn.groupby('tenure')['tenure'].count() # Se van mas lo que tienen un mes
# Out:
# tenure
# 1     380
# 2     123
# 3      94
# 4      83
# 5      64
#      ...
# 68      9
# 69      8
# 70     11
# 71      6
# 72      6
# Name: tenure, Length: 72, dtype: int64

# %%
#Agrupando por tiempo de servicio de los que no se van
no_churn.groupby('tenure')['tenure'].count() # Se van mas lo que tienen un mes
# Out:
# tenure
# 0      11
# 1     233
# 2     115
# 3     106
# 4      93
#      ...
# 68     91
# 69     87
# 70    108
# 71    164
# 72    356
# Name: tenure, Length: 73, dtype: int64

# %%
# Desempaqueta correctamente la tupla devuelta por plt.subplots
fig, ax = plt.subplots(1, 1, figsize=(10, 4))

# Grafica los datos en el único objeto Axes
ax.plot(yes_churn.groupby('tenure')['tenure'].count(), label='Usuarios evadidos')
ax.plot(no_churn.groupby('tenure')['tenure'].count(), label='Usuarios actuales')

# Agrega etiquetas y título para una mejor legibilidad
ax.set_xlabel('Duración (Meses)')
ax.set_ylabel('Número de usuarios')
ax.set_title('Usuarios por duración y estatus de evasión')
ax.legend()

plt.show()

# Guarda la figura en un archivo PNG
fig.savefig('DuracionUsuarios_vs_curn.png')

# %%
#Agrupando por adulto mayor
yes_churn.groupby('SeniorCitizen')['SeniorCitizen'].count()
# Out:
# SeniorCitizen
# 0    1393
# 1     476
# Name: SeniorCitizen, dtype: int64

# %%
# --- Gráfico de Pastel ---
# Los gráficos de pastel son mejores para mostrar partes de un todo.
# Las dos categorías (Adulto Mayor 0 y 1) conforman el total de clientes evadidos.
fig, ax = plt.subplots(1, 1, figsize=(6, 6))

# Autopct muestra el porcentaje en las cuñas
ax.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'salmon'])
ax.set_title('Distribución de Clientes Evadidos por Estatus de Adulto Mayor (Gráfico de Pastel)')
ax.axis('equal')  # Aspecto igual asegura que el pastel se dibuja como un círculo.

plt.show()

# %%
#Obtenga los recuentos de cada categoría de persona mayor entre los clientes que se dieron de baja
churned_senior_citizen_counts = yes_churn.groupby('SeniorCitizen')['SeniorCitizen'].count()

# Obtenga los recuentos de cada categoría de persona mayor entre los clientes que no se han dado de baja
non_churned_senior_citizen_counts = no_churn.groupby('SeniorCitizen')['SeniorCitizen'].count()

# Asigne los valores binarios a etiquetas comprensibles para el eje x
labels = ['No Senior Citizen', 'Senior Citizen']

# Obtenga los recuentos para trazar, lo que garantiza que manejemos los casos en los que pueda faltar una categoría
churned_counts = [churned_senior_citizen_counts.get(0, 0), churned_senior_citizen_counts.get(1, 0)]
non_churned_counts = [non_churned_senior_citizen_counts.get(0, 0), non_churned_senior_citizen_counts.get(1, 0)]

#Crear figura y ejes
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Define el ancho de las barras y las posiciones en el eje x
bar_width = 0.35
x = np.arange(len(labels))

#Grafique las barras para los clientes que no se han dado de baja
rects1 = ax.bar(x - bar_width/2, non_churned_counts, bar_width, label='Usuarios actuales', color='skyblue')

# Grafique las barras para los clientes que se han dado de baja
rects2 = ax.bar(x + bar_width/2, churned_counts, bar_width, label='Usuarios evadidos', color='salmon')

# Agregue algo de texto para etiquetas, título y etiquetas de marca del eje x personalizadas, etc.
ax.set_xlabel('Estatus de Adulto Mayor')
ax.set_ylabel('Número de usuarios')
ax.set_title('Distribución de usuarios por estatus de evasión y estatus de adulto mayor')
ax.set_xticks(x) # Establezca las ubicaciones de las marcas de verificación para que estén en el medio de las dos barras
ax.set_xticklabels(labels) # Establecer las etiquetas para los ticks

# Agregar leyenda
ax.legend()

# Agregue recuentos en la parte superior de las barras
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 puntos de desplazamiento vertical
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)


# Ajustar el diseño para evitar que las etiquetas se superpongan
fig.tight_layout()


plt.show()

# %%
#Agrupando por subscripcion a películas, de los que se fueron
yes_churn.groupby('StreamingMovies')['StreamingMovies'].count()
# Out:
# StreamingMovies
# 0                      938
# 1                      818
# No internet service    113
# Name: StreamingMovies, dtype: int64

# %%
#Agrupando por subscripcion a películas, de los que se quedaron
no_churn.groupby('StreamingMovies')['StreamingMovies'].count()
# Out:
# StreamingMovies
# 0                      1847
# 1                      1914
# No internet service    1413
# Name: StreamingMovies, dtype: int64

# %%
#Agrupando por subscripcion a internet, de los que se fueron
yes_churn.groupby('InternetService')['InternetService'].count()
# Out:
# InternetService
# 0               113
# DSL             459
# Fiber optic    1297
# Name: InternetService, dtype: int64

# %%
#Agrupando por subscripcion a internet, de los que se quedaron
no_churn.groupby('InternetService')['InternetService'].count()
# Out:
# InternetService
# 0              1413
# DSL            1962
# Fiber optic    1799
# Name: InternetService, dtype: int64

# %%
#Agrupando por subscripcion a TV por streaming de los que se fueron
yes_churn.groupby('StreamingTV')['StreamingTV'].count()
# Out:
# StreamingTV
# 0                      942
# 1                      814
# No internet service    113
# Name: StreamingTV, dtype: int64

# %%
#Agrupando por subscripcion a TV por streaming de los que no se fueron
no_churn.groupby('StreamingTV')['StreamingTV'].count()
# Out:
# StreamingTV
# 0                      1868
# 1                      1893
# No internet service    1413
# Name: StreamingTV, dtype: int64

# %%
#Media de los gastos totales de los que se evadieron
yes_churn['Charges.Total'].mean()
# Out:
# np.float64(1531.7960941680044)

# %%
#Media de los gastos totales de los que se no evadieron
no_churn['Charges.Total'].mean()
# Out:
# np.float64(2549.9994974874376)

# %%
#Media de los gastos mensuales de los que se no evadieron
no_churn['Charges.Monthly'].mean()
# Out:
# np.float64(61.26512369540008)

# %%
#Media de los gastos mensuales de los que se evadieron
yes_churn['Charges.Monthly'].mean()
# Out:
# np.float64(74.44133226324237)

# %%
# Calcula la media de los cargos para clientes que se dieron de baja y los que no
mean_monthly_charges_churned = yes_churn['Charges.Monthly'].mean()
mean_total_charges_churned = yes_churn['Charges.Total'].mean()

mean_monthly_charges_non_churned = no_churn['Charges.Monthly'].mean()
mean_total_charges_non_churned = no_churn['Charges.Total'].mean()

# Datos para graficar
labels = ['Cargos Mensuales Promedio', 'Cargos Totales Promedio']
churned_means = [mean_monthly_charges_churned, mean_total_charges_churned]
non_churned_means = [mean_monthly_charges_non_churned, mean_total_charges_non_churned]

# Crear la figura y los ejes
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Definir el ancho de las barras y las posiciones en el eje x
bar_width = 0.35
x = np.arange(len(labels)) # Posiciones para los grupos de barras

# Graficar las barras para los clientes que no se dieron de baja
rects1 = ax.bar(x - bar_width/2, non_churned_means, bar_width, label='Usuarios actuales', color='skyblue')

# Graficar las barras para los clientes que se dieron de baja
rects2 = ax.bar(x + bar_width/2, churned_means, bar_width, label='Usuarios evadidos', color='salmon')

# Agregar texto para etiquetas, título y etiquetas personalizadas del eje x, etc.
ax.set_ylabel('Valor Promedio')
ax.set_title('Comparación del Promedio de Cargos por Estatus de Evasión')
ax.set_xticks(x) # Establecer las ubicaciones de las marcas para que estén en el medio de los dos grupos de barras
ax.set_xticklabels(labels) # Establecer las etiquetas para las marcas

# Agregar leyenda
ax.legend()

# Opcional: Agregar recuentos en la parte superior de las barras
def autolabel(rects):
    """Adjuntar una etiqueta de texto encima de cada barra en *rects*, mostrando su altura."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}', # Formato con 2 decimales
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # Desplazamiento vertical de 3 puntos
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

# Ajustar el diseño para evitar que las etiquetas se superpongan
fig.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
#Media duracion de contrato de los que se fueron
yes_churn['tenure'].mean()
# Out:
# np.float64(17.979133226324237)

# %%
#Media duracion de contrato de los que no se fueron
no_churn['tenure'].mean()
# Out:
# np.float64(37.56996521066873)

# %%
# Calcula la duración promedio para clientes que se dieron de baja y los que no
mean_tenure_churned = yes_churn['tenure'].mean()
mean_tenure_non_churned = no_churn['tenure'].mean()


# Datos para el gráfico de barras horizontales
labels = ['Promedio de Duración (Churn)', 'Promedio de Duración (No Churn)']
tenure_means = [mean_tenure_churned, mean_tenure_non_churned]


# Crea la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 5))


# Crea el gráfico de barras horizontales
# y las posiciones y de las barras se manejarán automáticamente por las etiquetas
bars = ax.barh(labels, tenure_means, color=['salmon', 'skyblue'])


# Agrega etiquetas y título
ax.set_xlabel('Promedio de Duración (Meses)')
ax.set_title('Comparación del Promedio de Duración (Tenure) por Estatus de Evasión')


#  Agrega los valores en las barras
for bar in bars:
    width = bar.get_width()
    label_y_pos = bar.get_y() + bar.get_height() / 2
    ax.text(width, label_y_pos, f'{width:.2f}', va='center')

plt.show()

# %%
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO     0  Female              0        1           1       9
# 1  0003-MKNFE     0    Male              0        0           0       9
# 2  0004-TLHLJ     1    Male              0        0           0       4
# 3  0011-IGKFF     1    Male              1        1           0      13
# 4  0013-EXCHZ     1  Female              1        1           0       3
#
#    PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0             1             0             DSL  ...                0
# 1             1             1             DSL  ...                0
# 2             1             0     Fiber optic  ...                1
# 3             1             0     Fiber optic  ...                1
# 4             1             0     Fiber optic  ...                0
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
print(df_no_churn['MultipleLines'].value_counts())
# Out:
# MultipleLines
# 0                   2541
# 1                   2121
# No phone service     512
# Name: count, dtype: int64

# %%
# Se asigna 0 a los "No phone service"
df['MultipleLines'] = df['MultipleLines'].replace({'No phone service': 0})
# Out:
# <ipython-input-184-bb6aa713c8a6>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['MultipleLines'] = df['MultipleLines'].replace({'No phone service': 0})

# %%
print(df_no_churn['MultipleLines'].value_counts())
# Out:
# MultipleLines
# 0                   2541
# 1                   2121
# No phone service     512
# Name: count, dtype: int64

# %%
print(df_yes_churn['MultipleLines'].value_counts())
# Out:
# MultipleLines
# 1                   850
# 0                   849
# No phone service    170
# Name: count, dtype: int64

# %%
df_yes_churn['MultipleLines'] = df_yes_churn['MultipleLines'].replace({'No phone service': 0})
# Out:
# <ipython-input-187-383f845780c0>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_yes_churn['MultipleLines'] = df_yes_churn['MultipleLines'].replace({'No phone service': 0})

# %%
print(df_yes_churn['MultipleLines'].value_counts())
# Out:
# MultipleLines
# 0    1019
# 1     850
# Name: count, dtype: int64

# %%
# Reemplace cualquier cadena vacía en la columna 'Churn' con NaN
df['Churn'] = df['Churn'].replace('', pd.NA) # Use pd.NA para el tipo de entero que permite valores nulos

# Ahora convierta la columna 'Churn' a un tipo numérico.
# Si espera solo 0 y 1 después de manejar las cadenas vacías, puede convertir a int64.
# Si reemplazó las cadenas vacías con pd.NA, use Int64 (I mayúscula) para el entero que permite valores nulos.
df['Churn'] = df['Churn'].astype('Int64')

# Opcionalmente, si desea tratar los valores NaN como 0 después de la conversión:
# df['Churn'] = df['Churn'].fillna(0).astype('int64')

print(df['Churn'].info())
print("\nRecuentos de valores después de la conversión:")
print(df['Churn'].value_counts(dropna=False)) # Verifique los recuentos de valores, incluyendo NaN
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   Int64
# dtypes: Int64(1)
# memory usage: 64.0 KB
# None
#
# Recuentos de valores después de la conversión:
# Churn
# 0       5174
# 1       1869
# <NA>     224
# Name: count, dtype: Int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7043 non-null   Int64
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   int64
#  5   Dependents        7267 non-null   int64
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   int64
#  8   MultipleLines     7267 non-null   int64
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Calcula la correlación entre la columna correcta 'MultipleLines' y 'Churn'
# Reemplaza 'phone.MultipleLines' con el nombre de columna real si es diferente
# Asumiendo que el nombre de columna correcto es 'phone.MultipleLines' basado en la inspección previa
# Asegúrate de que 'MultipleLines' sea numérica reemplazando los valores no numéricos
# Parece que 'No phone service' estaba presente y necesita ser manejado.
# Reemplaza 'No phone service' con 0
df['MultipleLines'] = df['MultipleLines'].replace({'No phone service': 0})


# Ahora calcula la correlación
correlation = df['MultipleLines'].corr(df['Churn'])

print(f"La correlación entre 'MultipleLines' y 'Churn' es: {correlation:.4f}")


# Alternativamente, calcula la matriz de correlación para las dos columnas
# correlation_matrix = df[['MultipleLines', 'Churn']].corr()
# print("\nMatriz de correlación:")
# print(correlation_matrix)
# Out:
# La correlación entre 'MultipleLines' y 'Churn' es: 0.0401

# %%
# Ahora calcula la correlación
# Asegúrate de que 'StreamingTV' sea numérica reemplazando los valores no numéricos
# Reemplaza 'No internet service' con 0
df['StreamingTV'] = df['StreamingTV'].replace({'No internet service': 0})

correlation = df['StreamingTV'].corr(df['Churn'])
print(f"La correlación entre 'StreamingTV' y 'Churn' es: {correlation:.4f}")
# Out:
# La correlación entre 'StreamingTV' y 'Churn' es: 0.0632
# <ipython-input-192-3650e96e38e9>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['StreamingTV'] = df['StreamingTV'].replace({'No internet service': 0})

# %%
# Now calculate the correlation
# Ensure 'StreamingTV' is numeric by replacing non-numeric values
# Replace 'No internet service' with 0


correlation = df['Cuentas.Diarias'].corr(df['Churn'])
print(f"La correlación entre 'Cuentas.Diarias' y 'Churn' es: {correlation:.4f}")
# Out:
# La correlación entre 'Cuentas.Diarias' y 'Churn' es: 0.1934

# %%
# Ahora calcula la correlación
# Asegúrate de que 'Charges.Total' sea numérica antes de calcular la correlación.
# Como ya manejaste los valores no numéricos y los valores nulos para 'Charges.Total' previamente,
# no necesitas realizar reemplazos adicionales aquí a menos que haya un problema nuevo.

correlation = df['Charges.Total'].corr(df['Churn'])
print(f"La correlación entre 'Charges.Total' y 'Churn' es: {correlation:.4f}")
# Out:
# La correlación entre 'Charges.Total' y 'Churn' es: -0.1983

# %%
# Crear una matriz de correlación para columnas numéricas seleccionadas
# Seleccionar algunas columnas numéricas para incluir en la matriz de correlación
numeric_cols = ['tenure', 'Charges.Monthly', 'Charges.Total', 'Cuentas.Diarias', 'Churn']

# Calcular la matriz de correlación
correlation_matrix = df[numeric_cols].corr()

# Crear un mapa de calor (heatmap) para la matriz de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matriz de Correlación de Columnas Numéricas Seleccionadas')
plt.show()

# %%
#Revisar cuantos tipos de contratos hay
df['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
#Contar los tipos de contrato de los no evadidos
no_churn.groupby('Contract')['Contract'].count()
# Out:
# Contract
# Month-to-month    2220
# One year          1307
# Two year          1647
# Name: Contract, dtype: int64

# %%
#Contar los tipos de contrato de los evadidos
yes_churn.groupby('Contract')['Contract'].count()
# Out:
# Contract
# Month-to-month    1655
# One year           166
# Two year            48
# Name: Contract, dtype: int64

# %%
#Estimar los porcentajes de cada tipo de contrato para loos evadidos y no evadidos
perc_contract_yes_churn = (yes_churn.groupby('Contract')['Contract'].count() / yes_churn.shape[0]) * 100
perc_contract_no_churn = (no_churn.groupby('Contract')['Contract'].count() / no_churn.shape[0]) * 100
print(perc_contract_yes_churn)
print(perc_contract_no_churn)
# Out:
# Contract
# Month-to-month    88.550027
# One year           8.881755
# Two year           2.568218
# Name: Contract, dtype: float64
# Contract
# Month-to-month    42.906842
# One year          25.260920
# Two year          31.832238
# Name: Contract, dtype: float64

# %%
# Calcular los porcentajes (asumiendo que esto se hizo correctamente antes)
perc_contract_yes_churn = (yes_churn.groupby('Contract')['Contract'].count() / yes_churn.shape[0]) * 100
perc_contract_no_churn = (no_churn.groupby('Contract')['Contract'].count() / no_churn.shape[0]) * 100

# Desempaquetar correctamente la tupla devuelta por plt.subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6)) # Se aumentó ligeramente el ancho de la figura

# Ajustar el espaciado entre los subplots
plt.subplots_adjust(wspace=0.4, hspace=0.4) # Se aumentó el espaciado

# Graficar en los objetos Axes en el arreglo axs usando bar()
axs[0].bar(perc_contract_yes_churn.index, perc_contract_yes_churn.values, color='salmon', label='Usuarios evadidos')
axs[1].bar(perc_contract_no_churn.index, perc_contract_no_churn.values, color='skyblue', label='Usuarios actuales')

# Agregar títulos y etiquetas a los subplots para mayor claridad
axs[0].set_title('Usuarios Evadidos por Tipo de Contrato')
axs[0].set_xlabel('Tipo de Contrato')
axs[0].set_ylabel('Porcentaje (%)')
# Eliminar el parámetro  inválido, 'rotation' es suficiente para rotar.
axs[0].tick_params(axis='x', rotation=45)
axs[0].legend()

axs[1].set_title('Usuarios Actuales por Tipo de Contrato')
axs[1].set_xlabel('Tipo de Contrato')
axs[1].set_ylabel('Porcentaje (%)')
# Eliminar el parámetro inválido, 'rotation' es suficiente para rotar.
axs[1].tick_params(axis='x', rotation=45)
axs[1].legend()

# Agregar etiquetas de porcentaje en la parte superior de las barras
def autolabel(ax, bars):
    """Adjuntar una etiqueta de texto encima de cada barra en *rects*, mostrando su altura."""
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}%', # Formato con 1 decimal
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # Desplazamiento vertical de 3 puntos
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(axs[0], axs[0].patches) # axs[0].patches obtiene la lista de barras (rectángulos)
autolabel(axs[1], axs[1].patches) # axs[1].patches obtiene la lista de barras (rectángulos)

fig.tight_layout() # Ajustar el diseño para evitar que las etiquetas se superpongan
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ##**Introducción**

# %% [markdown]
# ####La empresa Telecom X, nos solicitó que revisaron sus datos, porque ha detectado que muchos clientes han dejado la compañia("Churn"), y de ser posible que detectemos cual es la causa de que los clientes se este retirando de la compañia

# %% [markdown]
# ##**Limpieza y tratamiento de datos**

# %% [markdown]
# ####1. Se procedió a importar a un dataframe el archivo: 'TelecomX_Data' el cual viene de una API y esta en formato JSON.
# ####2. Se revisaron las primeras 5 lineas del dataframe.
# ####3. Por medio de df.info(), se obtuvo la información de que el df tiene 7267 lineas y 6 columnas, sólo las dos primeras columnas tiene información individual, en las restantes la información esta en forma de dicccionarios.
# ####4. Se procedió a extraer (normalizar) cada diccionario en un nuevo df, que al final se concatenaron con las dos promeras columnas, resultando en un df de 7267 lineas y 21 columnas.
# ####5. Se cambió el tipo de data de 'Charges.Total' a float64
# ####6. Se generó la columna cargos diarios.
# ####7. Las columnas con 'Yes', 'No' se cambiaron a 1,0.
# ####8. Se revisaron los valores nulos los que estaban en 'Charges.Total', se les asignó  el cargo.mensual

# %% [markdown]
# ##**Análisis y Exploración de Datos**

# %% [markdown]
# ###Se generaron df para evasores y usuarios que se mantinen, para compararlos resepcto al tiempo que permanecen con el servicio(tenure).
#
# ![DuracionUsuarios_vs_curn.png](data:image/png;base64,...)
# ###Se observa que la mayoria de los usuarios evadidos se van al primer mes.

# %% [markdown]
# ###Al comparar los usuarios evadidos y actuales respecto al estatus de adulto mayor.
# ![image.png](data:image/png;base64,...)
#
# ####Se observa que la mayoria de los evadidos no son adultos mayores(casi tres veces más)

# %% [markdown]
# ####Comparando el promedio de cargos totales y mensuales respecto a evacion y usuarios actuales.
# ![image.png](data:image/png;base64,...)
#
# ####Los evasores tienen un mayor cargo mensual  y un menor cargo total, respecto a los usuarios que permanecen.

# %% [markdown]
# #### Al comparar el promedio de duracion respecto al estatus de evasión.
# ![image.png](data:image/png;base64,...)
# ####Los clientes actuales tienen un promedio de duración de más del doble respecto a los  evasores.

# %% [markdown]
# ####Comparación respecto  al tipo de contrato.
# ![image.png](data:image/png;base64,...)
# ####Los evasores tiene en mayor proporción ( aproximadamente 2 a 1) contratos mes-a-mes respecto a los usuarios no evasores.

# %% [markdown]
# ####Matriz de correlacion entre evasión(churn) y variables numéricas seleccionadas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####La mayor correlación negativa es contra duración(tenure), la mayor correlación  positiva es respecto a cargos mensuales

# %% [markdown]
# #**Conclusiones**

# %% [markdown]
# #### 1. La mayoria de los evasores se van al primer mes.
# #### 2. El costo mensual de los evasores es mayor que el de los no evasores.
# #### 3. La mayoria de los evasores no son adultos mayores.
# #### 4. Los evasores tenian contratos mes-a-mes en mayor proporción.
# #### 5. El promedio de duracion de los evasores es de 17 meses vs 37 meses en los no evasores

# %% [markdown]
# #**Recomendaciones**

# %% [markdown]
# ####1. Ofrecerle paquetes anuales o mulitanuales a los clientes con una mejor tárifa mensual, incluyendole dos servicios de su elección entre : películas,TV,líneas multilpes, online-security.
# ####2. A los clientes nuevos ademas de ofrecerle lo anterior, incluirle un mes gratis.
